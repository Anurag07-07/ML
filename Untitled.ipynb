# %%
# ## Single Line Comment
# '''''' Multi Line Comment 

message = '''
dgsahdghgashjgd
djsgahdgas
dgasfdg

'''

print(message)

# Python is Case Sensitive 
name = "AJ"
Name = "BJ"
print(name)
print(Name)
# Out:
# dgsahdghgashjgd
# djsgahdgas
# dgasfdg
#
#
# AJ
# BJ

# %%
## Indentation
## Consistent use of spaces
age = 45
if age>32:
    print("Old")
# Out:
# Old

# %%
## Line Continuation
total = 1+2+\
3+5
print(total)
# Out:
# 11

# %%
## Multiple Statement on single line
x = 45;z= x+56

# Type Inference
print(type(z))
print(z)
# Out:
# <class 'int'>
# 101

# %% [markdown]
# # Variables

# %%
age = 21
print(f"My age is {age}")
_name = "AJ"
print("My name is ",_name,type(_name))
message = '''Python is Dynamically Typed variable determined at runtime'''
print(message,type(message))
# Out:
# My age is 21
# My name is  AJ <class 'str'>
# Python is Dynamically Typed variable determined at runtime <class 'str'>

# %%
age = 25
print(type(age))
string_val = str(age)
print(string_val,type(string_val))
age2 = int(string_val)
print(age2,type(age2))
age2 = float(string_val)
print(age2,type(age2))
# Out:
# <class 'int'>
# 25 <class 'str'>
# 25 <class 'int'>
# 25.0 <class 'float'>

# %%
# Python allows the type of the var when program executes
age = int(input("Enter The Age"))
print(f"The Age is {age} and type is {type(str(age))}")
# Out:
# Enter The Age 12
# The Age is 12 and type is <class 'str'>

# %% [markdown]
# # Data Types

# %%
#int float string
a = 10;b=2.5;c="something"
print(f"Integer {a} Float {b} String {c} Bool {45>50}")
# Out:
# Integer 10 Float 2.5 String something Bool False

# %%
# result = "AJ"+7 #not Possible
result = "AJ"+str(7) # Possible
print(result)
# Out:
# AJ7

# %% [markdown]
# # Operators

# %%
# Arithmetic Operators
a = 10
b = 10

print(a+b)
print(a-b)
print(a/b) # Floor Value
print(a//b) # Integer Value
print(a**b)  # Power Operator
print(a*b)
print(a%b)

# Comparison
print(a>b)
print(a>=b)
print(a<b)
print(a<=b)
print(a==b)
print(a!=b)

#Logical Operator 
print(True and False)
print(a or b)
print( not 0)
# Out:
# 20
# 0
# 1.0
# 1
# 10000000000
# 100
# 0
# False
# True
# False
# True
# True
# False
# False
# 10
# True
